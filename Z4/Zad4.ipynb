# %%
import numpy as np
from tensorflow import keras
from keras import Sequential
from keras.layers import Dense, Input
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.preprocessing import OneHotEncoder, LabelEncoder

# Wczytanie danych z pliku CSV
features = pd.read_csv("vectors_100.csv", sep=',') # Otworzenie csv
data = np.array(features) # Konwersja na tablicę
X = (data[:,:-1]).astype('float64') # Wyodrębnianie wektora cech do macierzy X
Y = data[:,-1] # Wyodrębnianie etykiety kategorii do wektora Y

# Kodowanie etykiet klas jako liczby całkowite
label_encoder = LabelEncoder() # Inicjalizacja przekształtnika etykiet na liczby całkowite
y_int = label_encoder.fit_transform(Y) # Przekształcenie etykiet na liczby całkowite

# Kodowanie etykiet klas One-hot
onehot_encoder = OneHotEncoder(sparse_output=False) # Inicjalizacja kodera One-hot
y_onehot = onehot_encoder.fit_transform(y_int.reshape(-1, 1)) # Przekształcenie etykiet na kodowanie One-hot

# Podział danych na zbiór treningowy i testowy
X_train, X_test, y_train, y_test = train_test_split(X, y_onehot, test_size=0.3) # Podział danych na 70% treningowych i 30% testowych

# Tworzenie modelu sieci neuronowej
n_classes = y_train.shape[1] # Liczba klas na podstawie liczby kolumn w y_train
model = Sequential() # Inicjalizacja modelu sekwencyjnego
input_dim = X.shape[1]  # Dynamicznie wyznanaczanie liczba kolumn w zbiorze cech
model.add(Input(shape=(input_dim,))) # Dodanie warstwy wejściowej
model.add(Dense(10, activation='sigmoid')) # Dodanie warstwy ukrytej z 10 neuronami i funkcją aktywacji sigmoid
model.add(Dense(n_classes, activation='softmax')) # Dodanie warstwy wyjściowej z n_classes neuronami i funkcją aktywacji softmax

# Kompilacja modelu
model.compile(loss='categorical_crossentropy', optimizer='sgd', metrics=['accuracy']) # Kompilacja modelu z funkcją straty 'categorical_crossentropy', optymalizatorem 'sgd' i metryką 'accuracy'

# Uczenie sieci
model.fit(X_train, y_train, epochs=100, batch_size=10, shuffle=True) # Trenowanie modelu przez 100 epok z rozmiarem partii 10 i losowym przetasowaniem danych

# Testowanie sieci
y_pred = model.predict(X_test) # Predykcja na zbiorze testowym
y_pred_classes = np.argmax(y_pred, axis=1) # Wyodrębnienie klas z predykcji
y_test_classes = np.argmax(y_test, axis=1) # Wyodrębnienie klas z etykiet testowych

conf_matrix = confusion_matrix(y_test_classes, y_pred_classes) # Obliczenie macierzy pomyłek
print(conf_matrix) # Wyświetlenie macierzy pomyłek
# Out:
# Epoch 1/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.3038 - loss: 1.4655
# Epoch 2/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5484 - loss: 1.1937
# Epoch 3/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.2056 - loss: 1.3480
# Epoch 4/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3624 - loss: 1.2656
# Epoch 5/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6878 - loss: 1.1197
# Epoch 6/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6987 - loss: 1.0518
# Epoch 7/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7592 - loss: 1.0450
# Epoch 8/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7311 - loss: 0.9666
# Epoch 9/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7144 - loss: 1.0307
# Epoch 10/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7563 - loss: 0.9836
# Epoch 11/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7881 - loss: 0.9428
# Epoch 12/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8629 - loss: 0.8875
# Epoch 13/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8566 - loss: 0.8577
# Epoch 14/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7608 - loss: 0.7987
# Epoch 15/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5629 - loss: 0.8852
# Epoch 16/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7511 - loss: 0.8213
# Epoch 17/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8493 - loss: 0.7654
# Epoch 18/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8886 - loss: 0.7374
# Epoch 19/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9311 - loss: 0.6894
# Epoch 20/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9236 - loss: 0.7549
# Epoch 21/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7678 - loss: 0.8036
# Epoch 22/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8003 - loss: 0.7143
# Epoch 23/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9110 - loss: 0.6884
# Epoch 24/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8757 - loss: 0.6165
# Epoch 25/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9134 - loss: 0.5821
# Epoch 26/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9803 - loss: 0.5356
# Epoch 27/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9314 - loss: 0.4984
# Epoch 28/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9356 - loss: 0.5870
# Epoch 29/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9651 - loss: 0.4757
# Epoch 30/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9866 - loss: 0.4448
# Epoch 31/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9051 - loss: 0.4974
# Epoch 32/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9753 - loss: 0.4124
# Epoch 33/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8975 - loss: 0.4487
# Epoch 34/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8755 - loss: 0.4996
# Epoch 35/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9953 - loss: 0.3632
# Epoch 36/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9420 - loss: 0.4498
# Epoch 37/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9977 - loss: 0.3487
# Epoch 38/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.3154
# Epoch 39/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9986 - loss: 0.3192
# Epoch 40/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9991 - loss: 0.3393
# Epoch 41/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9864 - loss: 0.4411
# Epoch 42/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.3662
# Epoch 43/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.3231
# Epoch 44/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9987 - loss: 0.3607
# Epoch 45/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.2842
# Epoch 46/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8522 - loss: 0.4922
# Epoch 47/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.2625
# Epoch 48/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.2504
# Epoch 49/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9528 - loss: 0.3091
# Epoch 50/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.2639
# Epoch 51/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9986 - loss: 0.2346
# Epoch 52/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9844 - loss: 0.2900
# Epoch 53/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.2217
# Epoch 54/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9957 - loss: 0.2441
# Epoch 55/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.2374
# Epoch 56/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.2049
# Epoch 57/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.2022
# Epoch 58/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.1965
# Epoch 59/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.1911
# Epoch 60/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.1883
# Epoch 61/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.1864
# Epoch 62/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9542 - loss: 0.2642
# Epoch 63/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.1845
# Epoch 64/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.1797
# Epoch 65/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.1999
# Epoch 66/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.1718
# Epoch 67/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 0.1663
# Epoch 68/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.1640
# Epoch 69/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.1628
# Epoch 70/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.1580
# Epoch 71/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.1543
# Epoch 72/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.1509
# Epoch 73/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.1464
# Epoch 74/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.1520
# Epoch 75/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.1478
# Epoch 76/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 0.1453
# Epoch 77/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.1407
# Epoch 78/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.1362
# Epoch 79/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.1337
# Epoch 80/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.1336
# Epoch 81/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.1347
# Epoch 82/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.1306
# Epoch 83/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.1275
# Epoch 84/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.1308
# Epoch 85/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.1252
# Epoch 86/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.1236
# Epoch 87/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.1217
# Epoch 88/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.1219
# Epoch 89/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.1186
# Epoch 90/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.1177
# Epoch 91/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.1156
# Epoch 92/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.1151
# Epoch 93/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.1170
# Epoch 94/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.1095
# Epoch 95/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.1105
# Epoch 96/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.1148
# Epoch 97/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.1056
# Epoch 98/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.1064
# Epoch 99/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.1076
# Epoch 100/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.1041
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# [[24  0  0  0]
#  [ 0 36  0  0]
#  [ 0  0 36  0]
#  [ 0  0  0 24]]

# %%
import numpy as np
from tensorflow import keras
from keras import Sequential
from keras.layers import Dense, Input
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.preprocessing import OneHotEncoder, LabelEncoder

# Wczytanie danych z pliku CSV
features = pd.read_csv("vectors_100.csv", sep=',') # Otworzenie csv
data = np.array(features) # Konwersja na tablicę
X = (data[:,:-1]).astype('float64') # Wyodrębnianie wektora cech do macierzy X
Y = data[:,-1] # Wyodrębnianie etykiety kategorii do wektora Y

# Kodowanie etykiet klas jako liczby całkowite
label_encoder = LabelEncoder() # Inicjalizacja przekształtnika etykiet na liczby całkowite
y_int = label_encoder.fit_transform(Y) # Przekształcenie etykiet na liczby całkowite

# Kodowanie etykiet klas One-hot
onehot_encoder = OneHotEncoder(sparse_output=False) # Inicjalizacja kodera One-hot
y_onehot = onehot_encoder.fit_transform(y_int.reshape(-1, 1)) # Przekształcenie etykiet na kodowanie One-hot

# Podział danych na zbiór treningowy i testowy
X_train, X_test, y_train, y_test = train_test_split(X, y_onehot, test_size=0.3) # Podział danych na 70% treningowych i 30% testowych

# Tworzenie modelu sieci neuronowej
n_classes = y_train.shape[1] # Liczba klas na podstawie liczby kolumn w y_train
model = Sequential() # Inicjalizacja modelu sekwencyjnego
input_dim = X.shape[1]  # Dynamicznie wyznanaczanie liczba kolumn w zbiorze cech
model.add(Input(shape=(input_dim,))) # Dodanie warstwy wejściowej
model.add(Dense(10, activation='sigmoid')) # Dodanie warstwy ukrytej z 10 neuronami i funkcją aktywacji sigmoid
model.add(Dense(n_classes, activation='softmax')) # Dodanie warstwy wyjściowej z n_classes neuronami i funkcją aktywacji softmax

# Kompilacja modelu
model.compile(loss='categorical_crossentropy', optimizer='sgd', metrics=['accuracy']) # Kompilacja modelu z funkcją straty 'categorical_crossentropy', optymalizatorem 'sgd' i metryką 'accuracy'

# Uczenie sieci
model.fit(X_train, y_train, epochs=100, batch_size=10, shuffle=True) # Trenowanie modelu przez 100 epok z rozmiarem partii 10 i losowym przetasowaniem danych

# Testowanie sieci
y_pred = model.predict(X_test) # Predykcja na zbiorze testowym
y_pred_classes = np.argmax(y_pred, axis=1) # Wyodrębnienie klas z predykcji
y_test_classes = np.argmax(y_test, axis=1) # Wyodrębnienie klas z etykiet testowych

conf_matrix = confusion_matrix(y_test_classes, y_pred_classes) # Obliczenie macierzy pomyłek
print(conf_matrix) # Wyświetlenie macierzy pomyłek
# Out:
# Epoch 1/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3353 - loss: 1.3162
# Epoch 2/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5926 - loss: 1.1718
# Epoch 3/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6825 - loss: 1.1482
# Epoch 4/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7293 - loss: 1.1132
# Epoch 5/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7880 - loss: 1.0112
# Epoch 6/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7496 - loss: 0.9933
# Epoch 7/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6899 - loss: 0.9919
# Epoch 8/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3371 - loss: 1.2150
# Epoch 9/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.2983 - loss: 1.1942
# Epoch 10/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4210 - loss: 1.1391
# Epoch 11/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5127 - loss: 1.0677
# Epoch 12/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7764 - loss: 0.9077
# Epoch 13/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7639 - loss: 0.8588
# Epoch 14/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7696 - loss: 0.8107
# Epoch 15/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6955 - loss: 0.8248
# Epoch 16/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7622 - loss: 0.7562
# Epoch 17/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8803 - loss: 0.7611
# Epoch 18/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9188 - loss: 0.7549
# Epoch 19/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8489 - loss: 0.7724
# Epoch 20/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8617 - loss: 0.6341
# Epoch 21/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8878 - loss: 0.7016
# Epoch 22/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7656 - loss: 0.7023
# Epoch 23/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7268 - loss: 0.8017
# Epoch 24/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7824 - loss: 0.8142
# Epoch 25/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8615 - loss: 0.6765
# Epoch 26/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8465 - loss: 0.7153
# Epoch 27/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7435 - loss: 0.7612
# Epoch 28/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7660 - loss: 0.6721
# Epoch 29/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8118 - loss: 0.6875
# Epoch 30/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9550 - loss: 0.6771
# Epoch 31/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7800 - loss: 0.7319
# Epoch 32/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9210 - loss: 0.6606
# Epoch 33/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9262 - loss: 0.6367
# Epoch 34/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9195 - loss: 0.6195
# Epoch 35/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9231 - loss: 0.5842
# Epoch 36/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7774 - loss: 0.6710
# Epoch 37/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8910 - loss: 0.6116
# Epoch 38/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9555 - loss: 0.5513
# Epoch 39/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9160 - loss: 0.5625
# Epoch 40/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9388 - loss: 0.5485
# Epoch 41/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9469 - loss: 0.5497
# Epoch 42/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9117 - loss: 0.5450
# Epoch 43/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9264 - loss: 0.5375
# Epoch 44/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9246 - loss: 0.5219
# Epoch 45/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8491 - loss: 0.5696
# Epoch 46/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7506 - loss: 0.6241
# Epoch 47/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9682 - loss: 0.5114
# Epoch 48/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9463 - loss: 0.4913
# Epoch 49/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9285 - loss: 0.5000
# Epoch 50/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9238 - loss: 0.4840
# Epoch 51/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9465 - loss: 0.4552
# Epoch 52/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9159 - loss: 0.5100
# Epoch 53/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8562 - loss: 0.4995
# Epoch 54/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9794 - loss: 0.4249
# Epoch 55/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9839 - loss: 0.4320
# Epoch 56/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8667 - loss: 0.4857
# Epoch 57/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9750 - loss: 0.4209
# Epoch 58/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9218 - loss: 0.4457
# Epoch 59/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8764 - loss: 0.4489
# Epoch 60/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9832 - loss: 0.3905
# Epoch 61/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.3659
# Epoch 62/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.3938
# Epoch 63/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.3803
# Epoch 64/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8841 - loss: 0.4320
# Epoch 65/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.3492
# Epoch 66/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.3399
# Epoch 67/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.3433
# Epoch 68/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.3339
# Epoch 69/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.3505
# Epoch 70/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.3369
# Epoch 71/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.3195
# Epoch 72/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.3109
# Epoch 73/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.3180
# Epoch 74/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.3016
# Epoch 75/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.2896
# Epoch 76/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.2793
# Epoch 77/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.2801
# Epoch 78/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.3000
# Epoch 79/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.2793
# Epoch 80/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9998 - loss: 0.2612
# Epoch 81/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.2835
# Epoch 82/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.2754
# Epoch 83/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.2742
# Epoch 84/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.2680
# Epoch 85/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.2569
# Epoch 86/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.2662
# Epoch 87/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.2436
# Epoch 88/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9863 - loss: 0.2765
# Epoch 89/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.2352
# Epoch 90/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.2385
# Epoch 91/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.2470
# Epoch 92/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.2388
# Epoch 93/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.2399
# Epoch 94/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.2224
# Epoch 95/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.2334
# Epoch 96/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.2189
# Epoch 97/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.2145
# Epoch 98/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.2205
# Epoch 99/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.2179
# Epoch 100/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.2165
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# [[29  0  0  0]
#  [ 0 32  0  0]
#  [ 0  0 35  0]
#  [ 0  0  0 24]]
